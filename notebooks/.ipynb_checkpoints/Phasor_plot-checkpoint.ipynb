# %% [markdown]
# # Calculate and Plot Phasor Plots

# %% [markdown]
# ## Set data path

# %%
from pathlib import Path
from matplotlib import pyplot as plt
import numpy as np
import napari
from PhasorPy import phasor, phasor_plot, rgb_coloring, phasor_circle, histogram_filtering,  ndmedian
from FLIM_phasor import *
from readPTU_FLIM import PTUreader
from matplotlib import colors

# %%
data_path = "C:/Users/mazo260d/Desktop/Conni_BiA_PoL/copied_for_Marcelo/single_image/raw_FLIM_data/single_FLIM_image.ptu"
# data_path = "C:/Users/cblei/Desktop/miniSabb_local/FLIM_file_formats/single_FLIM_image.ptu"

# %%
data_path = Path(data_path)
print(data_path)
# Out:
# C:\Users\mazo260d\Desktop\Conni_BiA_PoL\copied_for_Marcelo\single_image\raw_FLIM_data\single_FLIM_image.ptu

# %% [markdown]
# ## Open ptu file

# %%
ptu_file = PTUreader(data_path, print_header_data = False)
# Out:
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!

# %% [markdown]
# ## Get FLIM data

# %%
flim_data_stack, intensity_image = ptu_file.get_flim_data_stack()

# %% [markdown]
# ## Format data

# %% [markdown]
# Re-arange axes to have (x,y) by the end

# %%
flim_data_stack_for_napari = np.moveaxis(flim_data_stack, [0, 1], [-2, -1])

# %% [markdown]
# Get only first channel (the second channel for this image is empty)

# %%
flim_data_stack_for_napari = flim_data_stack_for_napari[0, :, :, :]

# %%
flim_data_stack_for_napari.shape
# Out:
# (270, 512, 512)

# %% [markdown]
# ## Plot FLIM

# %%
ptu_file._print_ptu_head()
# Out:
# Head ID                        Value
# File_GUID                      40
# File_CreatingTime              13301658052.442
# $StartedByRemoteInterface      1
# Measurement_SubMode            3
# File_Comment
# TTResult_StopReason            1
# Fast_Load_End                  0
# CreatorSW_Name                 SymPhoTime 64
# CreatorSW_Version              1.6
# CreatorSW_SVNBuild             3224
# CreatorSW_Modules              0
# $ReqHdr_RecordVersion          16777728
# $ReqHdr_MeasurementType        1
# $ReqHdr_PixelNumber_X          512
# $ReqHdr_PixelNumber_Y          512
# $ReqHdr_ScanningPattern        0
# $ReqHdr_SpatialResolution      0.07035765166
# $Filename                      single_FLIM_image
# $Comment
# $Groupname                     single_FLIM_image
# ImgHdr_Dimensions              3
# ImgHdr_Ident                   3
# ImgHdr_PixX                    512
# ImgHdr_PixY                    512
# ImgHdr_PixResol                0.07035765166
# ImgHdr_LineStart               1
# ImgHdr_LineStop                2
# ImgHdr_Frame                   3
# ImgHdr_BiDirect                0
# ImgHdr_SinCorrection           0
# Measurement_Mode               3
# HW_Type                        PicoHarp
# HW_SerialNo                    1020815
# HW_Version                     2.0
# HW_ExternalRefClock            0
# HW_Modules                     1
# HWModule_TypeCode              1000
# HWModule_VersCode              536870912
# HW_Markers                     4
# HWMarkers_Enabled              1
# HWMarkers_RisingEdge           0
# HW_BaseResolution              96.96969697
# MeasDesc_BinningFactor         1
# MeasDesc_Resolution            9.696969697e-11
# HWSync_CFDLevel                100
# HWSync_CFDZeroCross            10
# HWSync_Offset                  0
# HWSync_Divider                 1
# HW_InpChannels                 2
# HWInpChan_CFDLeveld           100
# HWInpChan_CFDZeroCross         10
# HWInpChan_Offset               0
# HWInpChan_Enabled              1
# HWInpChan_ModuleIdx            1
# HWRouter_ModelCode             3
# HWRouter_Version               1.0
# HWRouter_Channels              4
# HWRouter_Enabled               1
# HWRouterChan_InputType         0
# HWRouterChan_InputLevel        -200
# HWRouterChan_RisingEdge        0
# HWRouterChan_CFDPresent        0
# HWRouterChan_CFDLevel          100
# HWRouterChan_CFDZeroCross      100
# TTResult_SyncRate              39010000
# TTResult_InputRate             815
# MeasDesc_GlobalResolution      2.563445270443476e-08
# TTResult_NumberOfRecords       13470734
# MeasDesc_AcquisitionTime       0
# TTResultFormat_TTTRRecType     66307
# TTResultFormat_BitsPerRecord   32
# Header_End                     4600

# %%
laser_frequency = ptu_file.head['TTResult_SyncRate'] *1E-6 #MHz
time_array = create_time_array(laser_frequency, n_points = flim_data_stack_for_napari.shape[0])
mean_intensity = np.mean(flim_data_stack_for_napari, axis=(1,2))
plt.plot(time_array, mean_intensity, label = 'image average over time')
start_index = np.argmax(mean_intensity)
time_mask = time_array >= time_array[start_index]
plt.plot(time_array[start_index], mean_intensity[start_index], 'r*', label = 'starting point')
plt.legend()

# %% [markdown]
# ## Phasor Plot

# %%
threshold = 43
tau_list = [0.5, 1, 2, 3, 4, 5, 6]

# %%
number_of_harmonics = 2
fig, ax = plt.subplots(number_of_harmonics, 1, figsize=(8, number_of_harmonics*5))
for i in range(number_of_harmonics):
    g, s, dc = get_phasor_components(flim_data_stack_for_napari[time_mask], harmonic = i+1)
    x, y = histogram_filtering(dc, g, s, threshold)
    
#     x = np.ravel(g)
#     y = np.ravel(s)
    
    if number_of_harmonics == 1:
        current_axis = ax
    else:
        current_axis = ax[i]
    
    add_phasor_circle(current_axis)
    add_tau_lines(current_axis, tau_list, laser_frequency) 
    current_axis.hist2d(x, y, bins=256, norm='log', range=[[0, 1], [0, 0.6]], cmap = 'jet')
    title = 'Harmonic #' + str(i+1)
    current_axis.set_title(title)

# %% [markdown]
# Check if lines for harmonics bigger than 1 should be different

# %% [markdown]
# ## Median Filter

# %%
from scipy.signal import medfilt

# %%
from skimage.filters import median

# %%
filtered_image =  ndmedian(flim_data_stack_for_napari[time_mask], 2)

# %%
number_of_harmonics = 2
fig, ax = plt.subplots(number_of_harmonics, 1, figsize=(8, number_of_harmonics*5))
for i in range(number_of_harmonics):
    g, s, dc = get_phasor_components(filtered_image, harmonic = i+1)
    x, y = histogram_filtering(dc, g, s, threshold)
    
#     x = np.ravel(g)
#     y = np.ravel(s)
    
    if number_of_harmonics == 1:
        current_axis = ax
    else:
        current_axis = ax[i]
    
    add_phasor_circle(current_axis)
    add_tau_lines(current_axis, tau_list, laser_frequency) 
    current_axis.hist2d(x, y, bins=256, norm='log', range=[[0, 1], [0, 0.6]], cmap = 'jet')
    title = 'Harmonic #' + str(i+1)
    current_axis.set_title(title)
